# %% [markdown]
# # Mask R-CNN - Train on Open ImagesDataset

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt

# Root directory of the project
ROOT_DIR = os.path.abspath("../../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
from openimages import OpenImageDataset

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# ## Configurations

# %%
class OpenImagesConfig(Config):
    """
    """
    # Give the configuration a recognizable name
    NAME = "openimages"

    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    NUM_CLASSES = 602  # background + 3 shapes

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 1024
    IMAGE_MAX_DIM = 1024

    
config = OpenImagesConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                614
# IMAGE_MIN_DIM                  1024
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           openimages
# NUM_CLASSES                    602
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Notebook Preferences

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# ## Dataset
#
# Create a synthetic dataset
#
# Extend the Dataset class and add a method to load the shapes dataset, `load_shapes()`, and override the following methods:
#
# * load_image()
# * load_mask()
# * image_reference()

# %%
# Training dataset
PATH = os.path.abspath(os.path.join(ROOT_DIR, '../data/'))

dataset_train = OpenImageDataset()
dataset_train.load_dataset(PATH, 'train')
dataset_train.prepare()

# Validation dataset
dataset_val = OpenImageDataset()
dataset_val.load_dataset(PATH, 'validation')
dataset_val.prepare()
#dataset_val = ShapesDataset()
#dataset_val.load_shapes(50, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
#dataset_val.prepare()

# %% [markdown]
# ## Create Model

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)
# Out:
# WARNING:tensorflow:From /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:492: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:63: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3630: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3458: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1822: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1208: calling reduce_max_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1242: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/bartosz/open-images/Mask_RCNN/mrcnn/model.py:553: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# WARNING:tensorflow:From /home/bartosz/open-images/Mask_RCNN/mrcnn/utils.py:202: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/bartosz/open-images/Mask_RCNN/mrcnn/model.py:600: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead

# %%
# Which weights to start with?
init_with = "last"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)
# Out:
# Re-starting from epoch 19

# %% [markdown]
# ## Training
#
# Train in two stages:
# 1. Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass `layers='heads'` to the `train()` function.
#
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass `layers="all` to train all layers.

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
model.compile(config.LEARNING_RATE, config.LEARNING_MOMENTUM)
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=100, 
            layers='heads')
# Out:
# WARNING:tensorflow:From /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/optimizers.py:711: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
#
# Starting at epoch 19. LR=0.001
#
# Checkpoint Path: /home/bartosz/open-images/Mask_RCNN/logs/openimages20190926T0931/mask_rcnn_openimages_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# WARNING:tensorflow:From /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:675: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/callbacks.py:705: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/callbacks.py:708: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/engine/training.py:2039: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 20/100
#  999/1000 [============================>.] - ETA: 1s - loss: 1.3376 - rpn_class_loss: 0.0261 - rpn_bbox_loss: 0.4288 - mrcnn_class_loss: 0.3445 - mrcnn_bbox_loss: 0.2699 - mrcnn_mask_loss: 0.2683
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/engine/training.py:2197: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# 1000/1000 [==============================] - 1447s 1s/step - loss: 1.3405 - rpn_class_loss: 0.0262 - rpn_bbox_loss: 0.4298 - mrcnn_class_loss: 0.3459 - mrcnn_bbox_loss: 0.2701 - mrcnn_mask_loss: 0.2684 - val_loss: 1.5824 - val_rpn_class_loss: 0.0418 - val_rpn_bbox_loss: 0.4135 - val_mrcnn_class_loss: 0.4373 - val_mrcnn_bbox_loss: 0.4027 - val_mrcnn_mask_loss: 0.2871
# Epoch 21/100
# 1000/1000 [==============================] - 1364s 1s/step - loss: 1.2549 - rpn_class_loss: 0.0237 - rpn_bbox_loss: 0.4013 - mrcnn_class_loss: 0.3241 - mrcnn_bbox_loss: 0.2540 - mrcnn_mask_loss: 0.2518 - val_loss: 1.8653 - val_rpn_class_loss: 0.0149 - val_rpn_bbox_loss: 0.9687 - val_mrcnn_class_loss: 0.3520 - val_mrcnn_bbox_loss: 0.2799 - val_mrcnn_mask_loss: 0.2498
# Epoch 22/100
# 1000/1000 [==============================] - 1364s 1s/step - loss: 1.2697 - rpn_class_loss: 0.0254 - rpn_bbox_loss: 0.4007 - mrcnn_class_loss: 0.3179 - mrcnn_bbox_loss: 0.2658 - mrcnn_mask_loss: 0.2599 - val_loss: 1.6016 - val_rpn_class_loss: 0.0208 - val_rpn_bbox_loss: 0.6237 - val_mrcnn_class_loss: 0.3841 - val_mrcnn_bbox_loss: 0.3196 - val_mrcnn_mask_loss: 0.2535
# Epoch 23/100
# 1000/1000 [==============================] - 1366s 1s/step - loss: 1.2532 - rpn_class_loss: 0.0208 - rpn_bbox_loss: 0.3840 - mrcnn_class_loss: 0.3231 - mrcnn_bbox_loss: 0.2656 - mrcnn_mask_loss: 0.2597 - val_loss: 1.3806 - val_rpn_class_loss: 0.0191 - val_rpn_bbox_loss: 0.4011 - val_mrcnn_class_loss: 0.4146 - val_mrcnn_bbox_loss: 0.3130 - val_mrcnn_mask_loss: 0.2328
# Epoch 24/100
# 1000/1000 [==============================] - 1363s 1s/step - loss: 1.2571 - rpn_class_loss: 0.0262 - rpn_bbox_loss: 0.3886 - mrcnn_class_loss: 0.3214 - mrcnn_bbox_loss: 0.2623 - mrcnn_mask_loss: 0.2586 - val_loss: 1.2147 - val_rpn_class_loss: 0.0182 - val_rpn_bbox_loss: 0.3484 - val_mrcnn_class_loss: 0.3386 - val_mrcnn_bbox_loss: 0.2709 - val_mrcnn_mask_loss: 0.2387
# Epoch 25/100
# 1000/1000 [==============================] - 1358s 1s/step - loss: 1.2578 - rpn_class_loss: 0.0230 - rpn_bbox_loss: 0.4043 - mrcnn_class_loss: 0.3127 - mrcnn_bbox_loss: 0.2594 - mrcnn_mask_loss: 0.2584 - val_loss: 1.4162 - val_rpn_class_loss: 0.0250 - val_rpn_bbox_loss: 0.4161 - val_mrcnn_class_loss: 0.3215 - val_mrcnn_bbox_loss: 0.3132 - val_mrcnn_mask_loss: 0.3403
# Epoch 26/100
# 1000/1000 [==============================] - 1369s 1s/step - loss: 1.2455 - rpn_class_loss: 0.0262 - rpn_bbox_loss: 0.3664 - mrcnn_class_loss: 0.3287 - mrcnn_bbox_loss: 0.2617 - mrcnn_mask_loss: 0.2625 - val_loss: 1.5958 - val_rpn_class_loss: 0.0301 - val_rpn_bbox_loss: 0.5975 - val_mrcnn_class_loss: 0.3711 - val_mrcnn_bbox_loss: 0.3423 - val_mrcnn_mask_loss: 0.2548
# Epoch 27/100
# 1000/1000 [==============================] - 1362s 1s/step - loss: 1.2620 - rpn_class_loss: 0.0241 - rpn_bbox_loss: 0.4219 - mrcnn_class_loss: 0.2988 - mrcnn_bbox_loss: 0.2564 - mrcnn_mask_loss: 0.2607 - val_loss: 1.6245 - val_rpn_class_loss: 0.0237 - val_rpn_bbox_loss: 0.7125 - val_mrcnn_class_loss: 0.3594 - val_mrcnn_bbox_loss: 0.2883 - val_mrcnn_mask_loss: 0.2406
# Epoch 28/100
# 1000/1000 [==============================] - 1370s 1s/step - loss: 1.2624 - rpn_class_loss: 0.0245 - rpn_bbox_loss: 0.3972 - mrcnn_class_loss: 0.3170 - mrcnn_bbox_loss: 0.2654 - mrcnn_mask_loss: 0.2583 - val_loss: 1.2690 - val_rpn_class_loss: 0.0149 - val_rpn_bbox_loss: 0.4021 - val_mrcnn_class_loss: 0.3202 - val_mrcnn_bbox_loss: 0.2818 - val_mrcnn_mask_loss: 0.2500
# Epoch 29/100
# 1000/1000 [==============================] - 1380s 1s/step - loss: 1.2379 - rpn_class_loss: 0.0232 - rpn_bbox_loss: 0.3708 - mrcnn_class_loss: 0.3227 - mrcnn_bbox_loss: 0.2553 - mrcnn_mask_loss: 0.2659 - val_loss: 1.6066 - val_rpn_class_loss: 0.0168 - val_rpn_bbox_loss: 0.7075 - val_mrcnn_class_loss: 0.3287 - val_mrcnn_bbox_loss: 0.3096 - val_mrcnn_mask_loss: 0.2440
# Epoch 30/100
# 1000/1000 [==============================] - 1373s 1s/step - loss: 1.2341 - rpn_class_loss: 0.0229 - rpn_bbox_loss: 0.3883 - mrcnn_class_loss: 0.3178 - mrcnn_bbox_loss: 0.2482 - mrcnn_mask_loss: 0.2568 - val_loss: 1.3381 - val_rpn_class_loss: 0.0194 - val_rpn_bbox_loss: 0.4289 - val_mrcnn_class_loss: 0.3738 - val_mrcnn_bbox_loss: 0.2715 - val_mrcnn_mask_loss: 0.2446
# Epoch 31/100
# Epoch 44/100
# 1000/1000 [==============================] - 1358s 1s/step - loss: 1.1730 - rpn_class_loss: 0.0231 - rpn_bbox_loss: 0.3489 - mrcnn_class_loss: 0.3149 - mrcnn_bbox_loss: 0.2341 - mrcnn_mask_loss: 0.2520 - val_loss: 1.3746 - val_rpn_class_loss: 0.0128 - val_rpn_bbox_loss: 0.5020 - val_mrcnn_class_loss: 0.2773 - val_mrcnn_bbox_loss: 0.3128 - val_mrcnn_mask_loss: 0.2697
# Epoch 45/100
# 1000/1000 [==============================] - 1357s 1s/step - loss: 1.1794 - rpn_class_loss: 0.0235 - rpn_bbox_loss: 0.3686 - mrcnn_class_loss: 0.3022 - mrcnn_bbox_loss: 0.2348 - mrcnn_mask_loss: 0.2502 - val_loss: 1.4005 - val_rpn_class_loss: 0.0137 - val_rpn_bbox_loss: 0.4712 - val_mrcnn_class_loss: 0.3390 - val_mrcnn_bbox_loss: 0.3062 - val_mrcnn_mask_loss: 0.2703
# Epoch 46/100
# 1000/1000 [==============================] - 1359s 1s/step - loss: 1.1425 - rpn_class_loss: 0.0224 - rpn_bbox_loss: 0.3283 - mrcnn_class_loss: 0.3105 - mrcnn_bbox_loss: 0.2296 - mrcnn_mask_loss: 0.2517 - val_loss: 1.2716 - val_rpn_class_loss: 0.0201 - val_rpn_bbox_loss: 0.4269 - val_mrcnn_class_loss: 0.3164 - val_mrcnn_bbox_loss: 0.2771 - val_mrcnn_mask_loss: 0.2311
# Epoch 47/100
# 1000/1000 [==============================] - 1360s 1s/step - loss: 1.1190 - rpn_class_loss: 0.0219 - rpn_bbox_loss: 0.3404 - mrcnn_class_loss: 0.2958 - mrcnn_bbox_loss: 0.2210 - mrcnn_mask_loss: 0.2400 - val_loss: 1.4733 - val_rpn_class_loss: 0.0171 - val_rpn_bbox_loss: 0.5300 - val_mrcnn_class_loss: 0.3711 - val_mrcnn_bbox_loss: 0.3135 - val_mrcnn_mask_loss: 0.2416
# Epoch 48/100
# 1000/1000 [==============================] - 1363s 1s/step - loss: 1.1307 - rpn_class_loss: 0.0229 - rpn_bbox_loss: 0.3439 - mrcnn_class_loss: 0.2987 - mrcnn_bbox_loss: 0.2259 - mrcnn_mask_loss: 0.2393 - val_loss: 1.3981 - val_rpn_class_loss: 0.0368 - val_rpn_bbox_loss: 0.4860 - val_mrcnn_class_loss: 0.3133 - val_mrcnn_bbox_loss: 0.2650 - val_mrcnn_mask_loss: 0.2970
# Epoch 49/100
# 1000/1000 [==============================] - 1365s 1s/step - loss: 1.1644 - rpn_class_loss: 0.0232 - rpn_bbox_loss: 0.3595 - mrcnn_class_loss: 0.3076 - mrcnn_bbox_loss: 0.2260 - mrcnn_mask_loss: 0.2480 - val_loss: 1.0573 - val_rpn_class_loss: 0.0149 - val_rpn_bbox_loss: 0.2597 - val_mrcnn_class_loss: 0.3262 - val_mrcnn_bbox_loss: 0.2379 - val_mrcnn_mask_loss: 0.2186
# Epoch 50/100
# 1000/1000 [==============================] - 1365s 1s/step - loss: 1.1617 - rpn_class_loss: 0.0248 - rpn_bbox_loss: 0.3432 - mrcnn_class_loss: 0.3130 - mrcnn_bbox_loss: 0.2314 - mrcnn_mask_loss: 0.2492 - val_loss: 1.1319 - val_rpn_class_loss: 0.0145 - val_rpn_bbox_loss: 0.2826 - val_mrcnn_class_loss: 0.3705 - val_mrcnn_bbox_loss: 0.2175 - val_mrcnn_mask_loss: 0.2469
# Epoch 51/100
# 1000/1000 [==============================] - 1363s 1s/step - loss: 1.1324 - rpn_class_loss: 0.0198 - rpn_bbox_loss: 0.3215 - mrcnn_class_loss: 0.3019 - mrcnn_bbox_loss: 0.2348 - mrcnn_mask_loss: 0.2544 - val_loss: 1.3126 - val_rpn_class_loss: 0.0123 - val_rpn_bbox_loss: 0.4310 - val_mrcnn_class_loss: 0.3326 - val_mrcnn_bbox_loss: 0.2807 - val_mrcnn_mask_loss: 0.2559
# Epoch 52/100
# 1000/1000 [==============================] - 1363s 1s/step - loss: 1.1389 - rpn_class_loss: 0.0217 - rpn_bbox_loss: 0.3461 - mrcnn_class_loss: 0.2962 - mrcnn_bbox_loss: 0.2260 - mrcnn_mask_loss: 0.2489 - val_loss: 1.3386 - val_rpn_class_loss: 0.0140 - val_rpn_bbox_loss: 0.4877 - val_mrcnn_class_loss: 0.2944 - val_mrcnn_bbox_loss: 0.2683 - val_mrcnn_mask_loss: 0.2742
# Epoch 53/100
# 1000/1000 [==============================] - 1358s 1s/step - loss: 1.1564 - rpn_class_loss: 0.0233 - rpn_bbox_loss: 0.3623 - mrcnn_class_loss: 0.3028 - mrcnn_bbox_loss: 0.2227 - mrcnn_mask_loss: 0.2454 - val_loss: 1.0186 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 0.2698 - val_mrcnn_class_loss: 0.2760 - val_mrcnn_bbox_loss: 0.2648 - val_mrcnn_mask_loss: 0.1987
# Epoch 54/100
# 1000/1000 [==============================] - 1360s 1s/step - loss: 1.1454 - rpn_class_loss: 0.0255 - rpn_bbox_loss: 0.3556 - mrcnn_class_loss: 0.2836 - mrcnn_bbox_loss: 0.2269 - mrcnn_mask_loss: 0.2538 - val_loss: 1.4250 - val_rpn_class_loss: 0.0210 - val_rpn_bbox_loss: 0.6235 - val_mrcnn_class_loss: 0.3195 - val_mrcnn_bbox_loss: 0.2593 - val_mrcnn_mask_loss: 0.2017
# Epoch 55/100
# 1000/1000 [==============================] - 1363s 1s/step - loss: 1.1604 - rpn_class_loss: 0.0243 - rpn_bbox_loss: 0.3608 - mrcnn_class_loss: 0.2908 - mrcnn_bbox_loss: 0.2327 - mrcnn_mask_loss: 0.2518 - val_loss: 1.2475 - val_rpn_class_loss: 0.0234 - val_rpn_bbox_loss: 0.4780 - val_mrcnn_class_loss: 0.2550 - val_mrcnn_bbox_loss: 0.2668 - val_mrcnn_mask_loss: 0.2243
# Epoch 56/100
# Epoch 70/100
# 1000/1000 [==============================] - 1352s 1s/step - loss: 1.1406 - rpn_class_loss: 0.0230 - rpn_bbox_loss: 0.3554 - mrcnn_class_loss: 0.2882 - mrcnn_bbox_loss: 0.2258 - mrcnn_mask_loss: 0.2482 - val_loss: 1.3341 - val_rpn_class_loss: 0.0161 - val_rpn_bbox_loss: 0.4199 - val_mrcnn_class_loss: 0.3626 - val_mrcnn_bbox_loss: 0.2533 - val_mrcnn_mask_loss: 0.2821
# Epoch 71/100
# 1000/1000 [==============================] - 1346s 1s/step - loss: 1.1393 - rpn_class_loss: 0.0228 - rpn_bbox_loss: 0.3532 - mrcnn_class_loss: 0.2961 - mrcnn_bbox_loss: 0.2156 - mrcnn_mask_loss: 0.2517 - val_loss: 1.0117 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 0.2933 - val_mrcnn_class_loss: 0.2887 - val_mrcnn_bbox_loss: 0.2328 - val_mrcnn_mask_loss: 0.1890
# Epoch 72/100
# 1000/1000 [==============================] - 1363s 1s/step - loss: 1.1483 - rpn_class_loss: 0.0252 - rpn_bbox_loss: 0.3528 - mrcnn_class_loss: 0.3007 - mrcnn_bbox_loss: 0.2190 - mrcnn_mask_loss: 0.2506 - val_loss: 1.4082 - val_rpn_class_loss: 0.0180 - val_rpn_bbox_loss: 0.6553 - val_mrcnn_class_loss: 0.2795 - val_mrcnn_bbox_loss: 0.2351 - val_mrcnn_mask_loss: 0.2204
# Epoch 73/100
# 1000/1000 [==============================] - 1365s 1s/step - loss: 1.1371 - rpn_class_loss: 0.0254 - rpn_bbox_loss: 0.3308 - mrcnn_class_loss: 0.3123 - mrcnn_bbox_loss: 0.2206 - mrcnn_mask_loss: 0.2480 - val_loss: 1.1919 - val_rpn_class_loss: 0.0115 - val_rpn_bbox_loss: 0.3541 - val_mrcnn_class_loss: 0.3323 - val_mrcnn_bbox_loss: 0.2619 - val_mrcnn_mask_loss: 0.2321
# Epoch 74/100
# 1000/1000 [==============================] - 1359s 1s/step - loss: 1.1110 - rpn_class_loss: 0.0265 - rpn_bbox_loss: 0.3171 - mrcnn_class_loss: 0.3035 - mrcnn_bbox_loss: 0.2179 - mrcnn_mask_loss: 0.2460 - val_loss: 1.2975 - val_rpn_class_loss: 0.0213 - val_rpn_bbox_loss: 0.3831 - val_mrcnn_class_loss: 0.3906 - val_mrcnn_bbox_loss: 0.2585 - val_mrcnn_mask_loss: 0.2439
# Epoch 75/100
# 1000/1000 [==============================] - 1337s 1s/step - loss: 1.1247 - rpn_class_loss: 0.0212 - rpn_bbox_loss: 0.3422 - mrcnn_class_loss: 0.3038 - mrcnn_bbox_loss: 0.2168 - mrcnn_mask_loss: 0.2407 - val_loss: 1.1557 - val_rpn_class_loss: 0.0134 - val_rpn_bbox_loss: 0.3260 - val_mrcnn_class_loss: 0.3196 - val_mrcnn_bbox_loss: 0.2605 - val_mrcnn_mask_loss: 0.2361
# Epoch 76/100
# Epoch 89/100
# 1000/1000 [==============================] - 1341s 1s/step - loss: 1.0311 - rpn_class_loss: 0.0200 - rpn_bbox_loss: 0.3031 - mrcnn_class_loss: 0.2795 - mrcnn_bbox_loss: 0.2004 - mrcnn_mask_loss: 0.2281 - val_loss: 1.1099 - val_rpn_class_loss: 0.0210 - val_rpn_bbox_loss: 0.3086 - val_mrcnn_class_loss: 0.3424 - val_mrcnn_bbox_loss: 0.2181 - val_mrcnn_mask_loss: 0.2196
# Epoch 90/100
# 1000/1000 [==============================] - 1344s 1s/step - loss: 1.0697 - rpn_class_loss: 0.0237 - rpn_bbox_loss: 0.3296 - mrcnn_class_loss: 0.2811 - mrcnn_bbox_loss: 0.2033 - mrcnn_mask_loss: 0.2320 - val_loss: 1.3224 - val_rpn_class_loss: 0.0253 - val_rpn_bbox_loss: 0.4707 - val_mrcnn_class_loss: 0.3074 - val_mrcnn_bbox_loss: 0.2704 - val_mrcnn_mask_loss: 0.2485
# Epoch 91/100
# 1000/1000 [==============================] - 1343s 1s/step - loss: 1.1100 - rpn_class_loss: 0.0206 - rpn_bbox_loss: 0.3452 - mrcnn_class_loss: 0.2910 - mrcnn_bbox_loss: 0.2085 - mrcnn_mask_loss: 0.2447 - val_loss: 1.2674 - val_rpn_class_loss: 0.0247 - val_rpn_bbox_loss: 0.4757 - val_mrcnn_class_loss: 0.3435 - val_mrcnn_bbox_loss: 0.2091 - val_mrcnn_mask_loss: 0.2144
# Epoch 92/100
# 1000/1000 [==============================] - 1342s 1s/step - loss: 1.0515 - rpn_class_loss: 0.0208 - rpn_bbox_loss: 0.3076 - mrcnn_class_loss: 0.2766 - mrcnn_bbox_loss: 0.2040 - mrcnn_mask_loss: 0.2423 - val_loss: 1.1313 - val_rpn_class_loss: 0.0182 - val_rpn_bbox_loss: 0.2665 - val_mrcnn_class_loss: 0.4110 - val_mrcnn_bbox_loss: 0.2423 - val_mrcnn_mask_loss: 0.1933
# Epoch 93/100
# 1000/1000 [==============================] - 1344s 1s/step - loss: 1.1466 - rpn_class_loss: 0.0227 - rpn_bbox_loss: 0.3587 - mrcnn_class_loss: 0.3071 - mrcnn_bbox_loss: 0.2194 - mrcnn_mask_loss: 0.2387 - val_loss: 1.1503 - val_rpn_class_loss: 0.0141 - val_rpn_bbox_loss: 0.2742 - val_mrcnn_class_loss: 0.3702 - val_mrcnn_bbox_loss: 0.2212 - val_mrcnn_mask_loss: 0.2706
# Epoch 94/100
# 1000/1000 [==============================] - 1347s 1s/step - loss: 1.0884 - rpn_class_loss: 0.0224 - rpn_bbox_loss: 0.3238 - mrcnn_class_loss: 0.2873 - mrcnn_bbox_loss: 0.2110 - mrcnn_mask_loss: 0.2439 - val_loss: 1.2032 - val_rpn_class_loss: 0.0153 - val_rpn_bbox_loss: 0.3982 - val_mrcnn_class_loss: 0.3122 - val_mrcnn_bbox_loss: 0.2396 - val_mrcnn_mask_loss: 0.2378
# Epoch 95/100
# 1000/1000 [==============================] - 1347s 1s/step - loss: 1.1122 - rpn_class_loss: 0.0228 - rpn_bbox_loss: 0.3430 - mrcnn_class_loss: 0.3024 - mrcnn_bbox_loss: 0.2060 - mrcnn_mask_loss: 0.2380 - val_loss: 1.1226 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.3654 - val_mrcnn_class_loss: 0.2834 - val_mrcnn_bbox_loss: 0.2273 - val_mrcnn_mask_loss: 0.2354
# Epoch 96/100
# 1000/1000 [==============================] - 1346s 1s/step - loss: 1.0688 - rpn_class_loss: 0.0220 - rpn_bbox_loss: 0.3346 - mrcnn_class_loss: 0.2901 - mrcnn_bbox_loss: 0.1941 - mrcnn_mask_loss: 0.2280 - val_loss: 0.9590 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.3255 - val_mrcnn_class_loss: 0.2651 - val_mrcnn_bbox_loss: 0.1977 - val_mrcnn_mask_loss: 0.1631
# Epoch 97/100
# 1000/1000 [==============================] - 1343s 1s/step - loss: 1.0608 - rpn_class_loss: 0.0212 - rpn_bbox_loss: 0.3135 - mrcnn_class_loss: 0.2821 - mrcnn_bbox_loss: 0.2066 - mrcnn_mask_loss: 0.2375 - val_loss: 1.1937 - val_rpn_class_loss: 0.0252 - val_rpn_bbox_loss: 0.3782 - val_mrcnn_class_loss: 0.2932 - val_mrcnn_bbox_loss: 0.2639 - val_mrcnn_mask_loss: 0.2333
# Epoch 98/100
# 1000/1000 [==============================] - 1344s 1s/step - loss: 1.0937 - rpn_class_loss: 0.0219 - rpn_bbox_loss: 0.3341 - mrcnn_class_loss: 0.2816 - mrcnn_bbox_loss: 0.2116 - mrcnn_mask_loss: 0.2445 - val_loss: 1.0453 - val_rpn_class_loss: 0.0127 - val_rpn_bbox_loss: 0.3275 - val_mrcnn_class_loss: 0.2649 - val_mrcnn_bbox_loss: 0.2122 - val_mrcnn_mask_loss: 0.2280
# Epoch 99/100
# 1000/1000 [==============================] - 1344s 1s/step - loss: 1.0625 - rpn_class_loss: 0.0215 - rpn_bbox_loss: 0.3070 - mrcnn_class_loss: 0.2915 - mrcnn_bbox_loss: 0.2045 - mrcnn_mask_loss: 0.2379 - val_loss: 1.0672 - val_rpn_class_loss: 0.0176 - val_rpn_bbox_loss: 0.2982 - val_mrcnn_class_loss: 0.3444 - val_mrcnn_bbox_loss: 0.1925 - val_mrcnn_mask_loss: 0.2145
# Epoch 100/100
# 1000/1000 [==============================] - 1347s 1s/step - loss: 1.0523 - rpn_class_loss: 0.0197 - rpn_bbox_loss: 0.3229 - mrcnn_class_loss: 0.2776 - mrcnn_bbox_loss: 0.2044 - mrcnn_mask_loss: 0.2277 - val_loss: 1.2389 - val_rpn_class_loss: 0.0181 - val_rpn_bbox_loss: 0.4571 - val_mrcnn_class_loss: 0.3083 - val_mrcnn_bbox_loss: 0.2283 - val_mrcnn_mask_loss: 0.2270

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also 
# pass a regular expression to select which layers to
# train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=120, 
            layers="all")
# Out:
# Starting at epoch 100. LR=0.0001
#
# Checkpoint Path: /home/bartosz/open-images/Mask_RCNN/logs/openimages20190926T0931/mask_rcnn_openimages_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# bn4r_branch2c          (BatchNorm)
# res4s_branch2a         (Conv2D)
# bn4s_branch2a          (BatchNorm)
# res4s_branch2b         (Conv2D)
# bn4s_branch2b          (BatchNorm)
# res4s_branch2c         (Conv2D)
# bn4s_branch2c          (BatchNorm)
# res4t_branch2a         (Conv2D)
# bn4t_branch2a          (BatchNorm)
# res4t_branch2b         (Conv2D)
# bn4t_branch2b          (BatchNorm)
# res4t_branch2c         (Conv2D)
# bn4t_branch2c          (BatchNorm)
# res4u_branch2a         (Conv2D)
# bn4u_branch2a          (BatchNorm)
# res4u_branch2b         (Conv2D)
# bn4u_branch2b          (BatchNorm)
# res4u_branch2c         (Conv2D)
# bn4u_branch2c          (BatchNorm)
# res4v_branch2a         (Conv2D)
# bn4v_branch2a          (BatchNorm)
# res4v_branch2b         (Conv2D)
# bn4v_branch2b          (BatchNorm)
# res4v_branch2c         (Conv2D)
# bn4v_branch2c          (BatchNorm)
# res4w_branch2a         (Conv2D)
# bn4w_branch2a          (BatchNorm)
# res4w_branch2b         (Conv2D)
# bn4w_branch2b          (BatchNorm)
# res4w_branch2c         (Conv2D)
# bn4w_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/engine/training.py:2039: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 101/120
#  999/1000 [============================>.] - ETA: 2s - loss: 1.0564 - rpn_class_loss: 0.0226 - rpn_bbox_loss: 0.3235 - mrcnn_class_loss: 0.2777 - mrcnn_bbox_loss: 0.1959 - mrcnn_mask_loss: 0.2368
# /home/bartosz/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/engine/training.py:2197: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# 1000/1000 [==============================] - 2114s 2s/step - loss: 1.0559 - rpn_class_loss: 0.0225 - rpn_bbox_loss: 0.3232 - mrcnn_class_loss: 0.2777 - mrcnn_bbox_loss: 0.1958 - mrcnn_mask_loss: 0.2367 - val_loss: 0.9373 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.2378 - val_mrcnn_class_loss: 0.2738 - val_mrcnn_bbox_loss: 0.1965 - val_mrcnn_mask_loss: 0.2210
# Epoch 102/120
# 1000/1000 [==============================] - 2058s 2s/step - loss: 1.0712 - rpn_class_loss: 0.0227 - rpn_bbox_loss: 0.3481 - mrcnn_class_loss: 0.2662 - mrcnn_bbox_loss: 0.1932 - mrcnn_mask_loss: 0.2410 - val_loss: 0.9751 - val_rpn_class_loss: 0.0182 - val_rpn_bbox_loss: 0.2720 - val_mrcnn_class_loss: 0.2674 - val_mrcnn_bbox_loss: 0.1797 - val_mrcnn_mask_loss: 0.2378
# Epoch 103/120
# 1000/1000 [==============================] - 2057s 2s/step - loss: 1.0217 - rpn_class_loss: 0.0211 - rpn_bbox_loss: 0.3251 - mrcnn_class_loss: 0.2543 - mrcnn_bbox_loss: 0.1889 - mrcnn_mask_loss: 0.2323 - val_loss: 1.3484 - val_rpn_class_loss: 0.0451 - val_rpn_bbox_loss: 0.5678 - val_mrcnn_class_loss: 0.3409 - val_mrcnn_bbox_loss: 0.1994 - val_mrcnn_mask_loss: 0.1952
# Epoch 104/120
# 1000/1000 [==============================] - 2059s 2s/step - loss: 1.0094 - rpn_class_loss: 0.0198 - rpn_bbox_loss: 0.2860 - mrcnn_class_loss: 0.2758 - mrcnn_bbox_loss: 0.1943 - mrcnn_mask_loss: 0.2333 - val_loss: 1.3377 - val_rpn_class_loss: 0.0412 - val_rpn_bbox_loss: 0.6379 - val_mrcnn_class_loss: 0.2373 - val_mrcnn_bbox_loss: 0.2003 - val_mrcnn_mask_loss: 0.2209
# Epoch 105/120
# 1000/1000 [==============================] - 2062s 2s/step - loss: 1.0082 - rpn_class_loss: 0.0207 - rpn_bbox_loss: 0.3116 - mrcnn_class_loss: 0.2610 - mrcnn_bbox_loss: 0.1817 - mrcnn_mask_loss: 0.2332 - val_loss: 1.2937 - val_rpn_class_loss: 0.0126 - val_rpn_bbox_loss: 0.5566 - val_mrcnn_class_loss: 0.2518 - val_mrcnn_bbox_loss: 0.2376 - val_mrcnn_mask_loss: 0.2352
# Epoch 106/120
# 1000/1000 [==============================] - 2060s 2s/step - loss: 0.9956 - rpn_class_loss: 0.0201 - rpn_bbox_loss: 0.3057 - mrcnn_class_loss: 0.2605 - mrcnn_bbox_loss: 0.1826 - mrcnn_mask_loss: 0.2267 - val_loss: 1.4383 - val_rpn_class_loss: 0.0148 - val_rpn_bbox_loss: 0.7255 - val_mrcnn_class_loss: 0.2933 - val_mrcnn_bbox_loss: 0.2000 - val_mrcnn_mask_loss: 0.2047
# Epoch 107/120
#  620/1000 [=================>............] - ETA: 12:48 - loss: 0.9662 - rpn_class_loss: 0.0215 - rpn_bbox_loss: 0.2922 - mrcnn_class_loss: 0.2594 - mrcnn_bbox_loss: 0.1684 - mrcnn_mask_loss: 0.2246
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-635a803652dd> in <module>
#       6             learning_rate=config.LEARNING_RATE / 10,
#       7             epochs=120,
# ----> 8             layers="all")
#
# ~/open-images/Mask_RCNN/mrcnn/model.py in train(self, train_dataset, val_dataset, learning_rate, epochs, layers, augmentation, custom_callbacks, no_augmentation_sources)
#    2372             max_queue_size=100,
#    2373             workers=workers,
# -> 2374             use_multiprocessing=True,
#    2375         )
#    2376         self.epoch = max(self.epoch, epochs)
#
# ~/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# ~/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2094                     outs = self.train_on_batch(x, y,
#    2095                                                sample_weight=sample_weight,
# -> 2096                                                class_weight=class_weight)
#    2097
#    2098                     if not isinstance(outs, list):
#
# ~/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1812             ins = x + y + sample_weights
#    1813         self._make_train_function()
# -> 1814         outputs = self.train_function(ins)
#    1815         if len(outputs) == 1:
#    1816             return outputs[0]
#
# ~/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2350         session = get_session()
#    2351         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2352                               **self.session_kwargs)
#    2353         return updated[:len(self.outputs)]
#    2354
#
# ~/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# ~/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# ~/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/.pyenv/versions/3.7.4/envs/open-images/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# Save weights
# Typically not needed because callbacks save after every epoch
# Uncomment to save manually
# model_path = os.path.join(MODEL_DIR, "mask_rcnn_shapes.h5")
# model.keras_model.save_weights(model_path)

# %% [markdown]
# ## Detection

# %%
class InferenceConfig(OpenImagesConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
model_path = model.find_last()

# Load trained weights
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)

# %%
# Test on a random image
image_id = random.choice(dataset_val.image_ids)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, inference_config, 
                           image_id, use_mini_mask=False)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_train.class_names, figsize=(8, 8))

# %%
results = model.detect([original_image], verbose=1)

r = results[0]
visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                            dataset_val.class_names, r['scores'], ax=get_ax())

# %% [markdown]
# ## Evaluation

# %%
# Compute VOC-Style mAP @ IoU=0.5
# Running on 10 images. Increase for better accuracy.
image_ids = np.random.choice(dataset_val.image_ids, 10)
APs = []
for image_id in image_ids:
    # Load image and ground truth data
    image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config,
                               image_id, use_mini_mask=False)
    molded_images = np.expand_dims(modellib.mold_image(image, inference_config), 0)
    # Run object detection
    results = model.detect([image], verbose=0)
    r = results[0]
    # Compute AP
    AP, precisions, recalls, overlaps =\
        utils.compute_ap(gt_bbox, gt_class_id, gt_mask,
                         r["rois"], r["class_ids"], r["scores"], r['masks'])
    APs.append(AP)
    
print("mAP: ", np.mean(APs))
